# %%
# coding: utf-8
"""
Created on Sun Jul 30 12:32:59 2017
@author: DIP
@Copyright: Dipanjan Sarkar
"""

# # Import necessary dependencies
import spacy
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
from contractions import contractions_dict
import unicodedata

nlp = spacy.load('en_core_web_sm')
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')


# # Cleaning Text - strip HTML
def strip_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    stripped_text = soup.get_text()
    return stripped_text


# # Removing accented characters
def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text


# # Expanding Contractions
#def expand_contractions(text, contraction_mapping=contractions_dict):
    
#    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
#                                      flags=re.IGNORECASE|re.DOTALL)
#    def expand_match(contraction):
#        match = contraction.group(0)
#        first_char = match[0]
#        expanded_contraction = contraction_mapping.get(match) \
#                                   if contraction_mapping.get(match) \
#                                    else contraction_mapping.get(match.lower())                       
#        expanded_contraction = first_char+expanded_contraction[1:]
#        return expanded_contraction
        
#    expanded_text = contractions_pattern.sub(expand_match, text)
#    expanded_text = re.sub("'", "", expanded_text)
#    return expanded_text


# # Removing Special Characters
def remove_special_characters(text):
    text = re.sub('[^a-zA-Z0-9\s]', '', text)
    return text


# # Lemmatizing text
def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text


# # Removing Stopwords
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text


# # Normalize text corpus - tying it all together
 #contraction_expansion=True,
def normalize_corpus(corpus, html_stripping=True, accented_char_removal=True, text_lower_case=True, text_lemmatization=True, special_char_removal=True, stopword_removal=True):
    
    normalized_corpus = []
    
    for doc in corpus:
        
        if html_stripping:
            doc = strip_html_tags(doc)
        
        if accented_char_removal:
            doc = remove_accented_chars(doc)
            
 #       if contraction_expansion:
 #           doc = expand_contractions(doc)
            
        if text_lower_case:
            doc = doc.lower()
            
        # remove extra newlines
        doc = re.sub(r'[\r|\n|\r\n]+', ' ',doc)
        # insert spaces between special characters to isolate them    
        special_char_pattern = re.compile(r'([{.(-)!}])')
        doc = special_char_pattern.sub(" \\1 ", doc)
        
        if text_lemmatization:
            doc = lemmatize_text(doc)
            
        if special_char_removal:
            doc = remove_special_characters(doc)  
            
        # remove extra whitespace
        doc = re.sub(' +', ' ', doc)
        
        if stopword_removal:
            doc = remove_stopwords(doc, is_lower_case=text_lower_case)
            
        normalized_corpus.append(doc)
        
    return normalized_corpus
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1f1f2c3324de> in <module>
#       7
#       8 # # Import necessary dependencies
# ----> 9 import spacy
#      10 import nltk
#      11 from nltk.tokenize.toktok import ToktokTokenizer
#
# ModuleNotFoundError: No module named 'spacy'

# %%
#https://srome.github.io/Understanding-Attention-in-Neural-Networks-Mathematically/
'''Attention has been shown to help achieve state of the art performance on many tasks, 
but it is also has the obvious advantage of explaining important 
components of neural networks to a practitioner.'''
import numpy as np
import pandas as pd
import re
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
df=pd.read_csv('/Users/johncase/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/corr_data.csv')
# Ensure that text variables are strings
df.xxxAllText = df.xxxAllText.astype(str)
df.CorroKeyword = df.CorroKeyword.astype(str)
df
# Out:
#                         CorroKeyword  \
# 0                              CHECK
# 1                              CHECK
# 2                              CHECK
# 3                            INSPECT
# 4                            INSPECT
# ...                              ...
# 1406227  Failure Code - 002 Air Leak
# 1406228  Failure Code - 002 Air Leak
# 1406229  Failure Code - 002 Air Leak
# 1406230  Failure Code - 002 Air Leak
# 1406231  Failure Code - 002 Air Leak
#
#                                                 xxxAllText  y
# 0        ENG CHECKOUT PROCEDURE REQ PER TM 1-2840-248-2...  1
# 1        MOC/ CHECK PROCEDURE FOR NEW AND REINSTALLED E...  1
# 2        LMTF/MAX PWR CHECK REQUIRED FOR MAINTENANCE PE...  1
# 3        INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN ...  1
# 4        INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN ...  1
# ...                                                    ... ..
# 1406227  AFT YELLOW ROD END NEEDS REPLACEMENT DUE TO PI...  1
# 1406228  C-BOX AUX PRESS SWIITCH DOES NOT GIVE SIGNAL R...  1
# 1406229  RAD ALT BACK LIGHT INOP PREFORMED OPERATIONAL ...  1
# 1406230  AFT GREEN TROOP WARNING LIGHT INOP COULD NOT R...  1
# 1406231  STA 440 NVG CABIN LIGHT INOP. REPLACED 2 DOME ...  1
#
# [1406232 rows x 3 columns]

# %%
# normalize corpus
norm_corpus = normalize_corpus(corpus=df['xxxAllText'], html_stripping=True, #contraction_expansion=True,
                     accented_char_removal=True, text_lower_case=True, 
                     text_lemmatization=True, special_char_removal=True, 
                     stopword_removal=True)
# Out:
# /opt/anaconda3/envs/tensorflow_cpu/lib/python3.6/site-packages/bs4/__init__.py:314: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
norm_corpus
# Out:
# ['eng checkout procedure req per tm 1 2840 248 23p wp 0111 table 1',
#  'moc check procedure new reinstall engine wp 0110 00 due maintenance perform 1 engine agb complete iaw tm 1 1520 237mtf',
#  'lmtf max pwr check require maintenance perform 1 engine agb per 1 2840 248 23p wp 0110 complete iaw tm 1 1520 237mtf',
#  'insp a022 14 day flyable storage engine run due 12jul2018 upgrade red x status 14jul2018 runup complete',
#  'insp a022 14 day flyable storage engine run due 26jul2018 upgrade x status 28jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 26jul2018 upgrade x status 28jul2018 complete',
#  '2 eng oil comsumption ck req due oil seeping c sump seal',
#  'main mod moc leak check due main mod oil filter replace drain plug remove reinstall moc complete fail leak check see fault 29 jul 18 3 iaw tm 1 1520 237mtf',
#  'engine load demand push pull friction check require removal lds cable support complete insp ok',
#  'run 2 engine least 10 minute let engine cool one hour minimum perform torque check 2 deswirl duct loop clamp nut tq chk comp',
#  'leak check require replacement first second stage main mod filter leak check ok',
#  'torque check 2 engine deswirl duct loop clamp nut next run iaw tm 1 1520 237 23p wp 0490 00 complete tq 45 lbs',
#  'idle speed leakage check require replacement 1 engine starter moc complete check find ok',
#  'insp a022 14 day flyable storage engine run due 25jul2018 upgrade x status 27jul2018 insp comp check ok',
#  'insp a022 14 day flyable storage engine run due 09jul2018 upgrade x status 11jul2018',
#  'lds rig due completion pmi2 complete insp ok',
#  'insp a100 lh rh engine history recorder reading due due 15aug2018 upgrade x status 19aug2018 reading take',
#  'insp a100 lh rh engine history recorder reading due due 15sep2018 upgrade x status 19sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15aug2018 upgrade x status 19aug2018 history recorder reading take',
#  'insp a100 lh rh engine history recorder reading due due 14jul2018 upgrade x status 18jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 01aug2018 upgrade x status 03aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 19jul2018 upgrade x status 23jul2018 engine history recording complete',
#  'insp a100 lh rh engine history recorder read due due 18jul2018 upgrade x status 22jul2018 complete',
#  'insp a533 pitot static system inspection due 27aug2018 upgrade x status 27sep2018 test operational check ok',
#  'pitot static system operational check rqrd replacement copilot altimeter moc complete check find ok',
#  '1 2 engine max performance check require engine reinstillation complete',
#  'insp a022 14 day flyable storage engine run due 03oct2018 upgrade x status 05oct2018 complete',
#  'insp a022 14 day flyable storage engine run due 26jul2018 upgrade x status 28jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 14sep2018 upgrade x status 16sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 16aug2018 upgrade x status 18aug2018 complete',
#  'load demand rid require no 1 no 2 engine cable removal cable end cable support complete insp ok',
#  'load demand rid require no 1 no 2 engine cable removal cable end cable support complete insp ok',
#  'insp a022 14 day flyable storage engine run due 12jul2018 upgrade x status 14jul2018 fly 10 jul 2018',
#  'insp a022 14 day flyable storage engine run due 08aug2018 upgrade x status 10aug2018',
#  'insp a022 14 day flyable storage engine run due 17aug2018 upgrade x status 19aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 29aug2018 upgrade x status 31aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 29aug2018 upgrade x status 31aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 11jul2018 upgrade x status 13jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 11jul2018 upgrade x status 13jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 11jul2018 upgrade x status 13jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 27jul2018 upgrade x status 29jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 09aug2018 upgrade x status 11aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 04sep2018 upgrade x status 06sep2018 complete',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 1 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng upr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'insp a100 lh rh engine history recorder read due due 14aug2018 upgrade x status 18aug2018 complete',
#  'insp a100 lh rh engine history recorder read due due 14sep2018 upgrade x status 18sep2018 complete',
#  'insp a100 lh rh engine history recorder read due due 14sep2018 upgrade x status 18sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14aug2018 upgrade x status 18aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 13sep2018 upgrade x status 17sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 21sep2018 upgrade x status 23sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 16jul2018 upgrade x status 20jul2018 ge e374751c lcf1 587 lcf2 2167 index 3729 hrs 1219 ge e307414c lcf1 259 lcf2 670 index 2165 hrs 915',
#  'insp a022 14 day flyable storage engine run due 14aug2018 upgrade x status 16aug2018 run comp',
#  'insp a022 14 day flyable storage engine run due 13sep2018 upgrade x status 15sep2018 engine run conjunction flight',
#  'insp a100 lh rh engine history recorder reading due due 13sep2018 upgrade x status 17sep2018 insp ok 6354 0 hrs apu n sp091899 hours0388 events2684 1 engine n ge e306712c hist rec n lmdh5496 lcf1 564 lcf2 1953 index4515 hours1340 2 engine n ge e991811 hist rec n lmdh4167 lcf1 618 lcf2 2186 index2732 hours1324',
#  'insp a022 14 day flyable storage engine run due 13jul2018 upgrade x status 15jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 13aug2018 upgrade x status 17aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 12jul2018 upgrade x status 14jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15sep2018 upgrade x status 19sep2018 insp comp',
#  'insp a100 lh rh engine history recorder reading due due 14sep2018 upgrade x status 18sep2018 eng 1 lcf1 1499 lcf2 7413 index 8105 hour 2420 eng 2 lcf1 0640 lcf2 3645 index 3013 hour 1365',
#  'insp a100 lh rh engine history recorder reading due due 13aug2018 upgrade x status 17aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14sep2018 upgrade x status 18sep2018 eng 1 lcf1 1736 lcf2 7344 index 12193 hour 3973 eng 2 lcf1 0215 lcf2 1469 index 01037 hour 0486',
#  'insp a100 lh rh engine history recorder reading due due 15jul2018 upgrade x status 19jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14aug2018 upgrade x status 18aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15sep2018 upgrade x status 19sep2018 complete',
#  'insp a533 pitot static system inspection due 29sep2018 upgrade x status 30oct2018',
#  'insp a533 pitot static system inspection due 04sep2018 upgrade x status 05oct2018 complete pitot static druck sn4051437',
#  'r cable tension check due 2514 7 1 acft hrs prev readings l h165 r h165 27 4 c adjust 160160 28 5 deg c iaw em 0284 wp 298',
#  'mtf require due replacement pitch trim servo mtf complete check find ok',
#  'insp a801 pmd expiration 7 day due 19sep2018 upgrade x status 20sep2018 complete',
#  'insp e357 replace apx123 transponder saft battery due 06oct2018 upgrade x status 06nov2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp e357 replace apx123 transponder saft battery due 06oct2018 upgrade x status 06nov2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp a801 pmd expiration 7 day due 10aug2018 upgrade x status 11aug2018 complete',
#  'insp a801 pmd expiration 7 day due 25sep2018 upgrade x status 26sep2018 complete',
#  'insp a801 pmd expiration 7 day due 25sep2018 upgrade x status 26sep2018 complete',
#  'insp a801 pmd expiration 7 day due 04aug2018 upgrade x status 05aug2018 complete',
#  'insp e200 esis power supply capacity discharge test due 18aug2018 upgrade x status 18sep2018 replace esis power supply n 80469 iaw em0284 wp 1681',
#  'insp e200 esis power supply capacity discharge test due 18aug2018 upgrade x status 18sep2018 replace esis power supply n 80469 iaw em0284 wp 1681',
#  'insp e330 water acoustic beacon battery replacement due 01nov2018 upgrade x status 02dec2018 replace water beacon battery iaw em 0284 w p 309',
#  'insp e330 water acoustic beacon battery replacement due 01nov2018 upgrade x status 02dec2018 replace water beacon battery iaw em 0284 w p 309',
#  'insp e357 replace apx123 transponder saft battery due 04sep2018 upgrade x status 05oct2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp e357 replace apx123 transponder saft battery due 04sep2018 upgrade x status 05oct2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp e330 water acoustic beacon battery replacement due 25sep2018 upgrade x status 26oct2018 replace water beacon battery iaw em 0284 w p 309',
#  'insp e330 water acoustic beacon battery replacement due 25sep2018 upgrade x status 26oct2018 replace water beacon battery iaw em 0284 w p 309',
#  'insp e357 replace apx123 transponder saft battery due 10sep2018 upgrade x status 11oct2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp e357 replace apx123 transponder saft battery due 10sep2018 upgrade x status 11oct2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp e357 replace apx123 transponder saft battery due 03sep2018 upgrade x status 04oct2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp e357 replace apx123 transponder saft battery due 03sep2018 upgrade x status 04oct2018 replace apx123 transponder battery iaw em 0284 w p 3039',
#  'insp a532 compass swing rmi due 22sep2018 upgrade x status 23oct2018 complete',
#  'insp a532 compass swing rmi due 22sep2018 upgrade x status 23oct2018 complete',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation 2 eng lwr ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'installation apu ir flame detector sensor pn 70310 00800 101 require per h60 18amam04 10jul20 replace iaw h60 18amam04 em284 wp1361',
#  'tail gearbox chip detector cannon plug backshell shielding come replace insulator material shielding not damage',
#  'ice detete caution appear autorotation disappear aircraft terminate hover incident repeat second autorotation pull tie ice detect cb see entry 6 date 24aug2018 icing restriction',
#  'ice detete caution appear autorotation disappear aircraft terminate hover incident repeat second autorotation pull tie ice detect cb see entry 6 date 24aug2018 icing restriction',
#  '2 engine p3 drain tube colgge remove inspect clean 2 eng p3 drain line tee fitting check valve',
#  'insp a022 14 day flyable storage engine run due 05jul2018 upgrade x status 07jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14aug2018 upgrade x status 18aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15jul2018 upgrade x status 19jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15aug2018 upgrade x status 19aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15sep2018 upgrade x status 19sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15aug2018 upgrade x status 19aug2018 reading take no 1 eng lcf11044 lcf24881 index7455 hrs1603 no 2 eng lcf157 lcf2481 index162 hrs124 apu hrs664 events4372',
#  'insp a100 lh rh engine history recorder reading due due 14aug2018 upgrade x status 18aug2018',
#  'insp a100 lh rh engine history recorder reading due due 14jul2018 upgrade x status 18jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 21jul2018 upgrade x status 25jul2018 ge e306191c lcf1 00461 lcf2 01677 index 02804 hrs 01130 ge e207362c lcf1 00451 lcf2 01532 index 02051 hrs 01115',
#  'insp a022 14 day flyable storage engine run due 21aug2018 upgrade x status 23aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 02aug2018 upgrade x status 04aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 06sep2018 upgrade x status 08sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 06sep2018 upgrade x status 08sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 06sep2018 upgrade x status 08sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14jul2018 upgrade x status 18jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 10aug2018 upgrade x status 12aug2018',
#  'insp a100 lh rh engine history recorder reading due due 14jul2018 upgrade x status 18jul2018 ge e306234c lcf1 00376 lcf2 01371 index 02606 hrs 00986 ge e307077c lcf1 00623 lcf2 02438 index 03697 hrs 01123',
#  'insp a022 14 day flyable storage engine run due 01sep2018 upgrade x status 03sep2018 c run flight',
#  'insp a100 lh rh engine history recorder reading due due 14sep2018 upgrade x status 18sep2018 eng1 lcf1 644 lcf2 2656 index 2234 hour 1239 eng2 lcf1 581 lcf2 2474 index 2434 hour 1223',
#  'insp a022 14 day flyable storage engine run due 16jul2018 upgrade x status 18jul2018 complete insp ok',
#  'insp a532 compass swing rmi due 22sep2018 upgrade x status 23oct2018 complete',
#  'pmd inspection due complete',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280 pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  '1 damage around air inlet bypass screen mount hole repair damage around mount hole require',
#  'postflight hydrualic fluid discover swedge forward utility hyd manifold connection apu start return line accumulator pressure within normal limit conduct leak ck no leak present',
#  'corrective action entry 2 date 18 jul 2018 drag torque ck incomplete drag torque ck comp power without power see original entry action',
#  'fault page show hpsm 1 fcr ckt brkr fail fcr not instal not effect misson',
#  'regard weapon entry 1 date 14sep2018 fault sign incorrectly list station 1 3 4 bit moc complete fault sign read station 1 thru 4 launcher bit moc complete iaw tm 1 1520longbowapache check good',
#  'fault 5 date 21 sep 18 miss inventory supervisor check fault note discuss sm conduct maintenance',
#  'collective servo corrision top utility hyd input check valve info entry see 2408 13 1 dtd 14 sep 2018 seq 11 related maintenance clean treat',
#  'entry 14sep2018 no 10 2408 13 2 seq 7 display processor reinstallation no torque bonding check list display processor bonding check complete ok 002 ohms mr 134624 torque 45inlbs mr136310 iaw tm 1 1520longbow apache',
#  'entry 1 seq 50 date 21 aug 2018 no 5 min apu run leak check drain plug comp iaw tm 1 1520longbow apache conjunction pms date 21 aug 2018',
#  'intermitent comms throughout flight ce right wing also intermitent comms break able transmit receive check no fault find',
#  '22 fastener loose top side tailboom check no fault find',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due complete',
#  'pmd inspection due complete',
#  'insp a801 7 day pmd inspection due 26aug2018 upgrade x status 27aug2018 complete',
#  'pmd inspection due complete',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'l h storage bay door not open check find serviceable 500 hr phase iaw tm 1 1520 longbow apache',
#  'lateral servo rigging null check reqd replacement lateral servo complete',
#  'gse fill port seep form drop flight gse primary pressure line b nut seep fluid well tq check complete 145 lbs verif sgt pavlyuchek',
#  'pnvs stick stutter look leave duplicate crew station allow efab cool 90 deg perform function check no fault find moc ok',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'torque check no 1 wing low mount require due phase maintenance inspection torque check complete',
#  'magnetic compass instrument light flicker flight standby instrument lighting check ok',
#  'mspu download indicate 3 main xmsn grbx accelerometer open check find okay',
#  'tr pitch link assembly sn unk require proof load test per h64 18amam05 5212 1 aircraft hour fault enter error compliance h64 18amam05 complete',
#  'tr pitch link assembly sn unk require proof load test per h64 18amam05 6684 0 aircraft hour amam comply refer fault 2 date 11 july related maintenance',
#  'insp a022 14 day flyable storage engine run due 16jul2018 upgrade x status 18jul2018 complete insp ok',
#  'insp a100 lh rh engine history recorder reading due due 15jul2018 upgrade x status 19jul2018 comp',
#  'insp a022 14 day flyable storage engine run due 23sep2018 upgrade x status 25sep2018 comp',
#  'insp a100 lh rh engine history recorder reading due due 13aug2018 upgrade x status 17aug2018 insp compl',
#  'insp a100 lh rh engine history recorder reading due due 13aug2018 upgrade x status 17aug2018',
#  'insp a100 lh rh engine history recorder reading due due 14aug2018 upgrade x status 18aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 02sep2018 upgrade x status 04sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 13jul2018 upgrade x status 15jul2018 14 day run complete',
#  'insp a022 14 day flyable storage engine run due 30jul2018 upgrade x status 01aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 16aug2018 upgrade x status 18aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 12jul2018 upgrade x status 14jul2018 14 day run complete',
#  'insp a022 14 day flyable storage engine run due 01aug2018 upgrade x status 03aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 13aug2018 upgrade x status 15aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14jul2018 upgrade x status 18jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 17jul2018 upgrade x status 19jul2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14sep2018 upgrade x status 18sep2018 2 n 991892 lc100073 lc200456 tti 00404 hrs 00114 hist n 6130 1s n 991840 lc1 00101 lc2 00386 tti 00537 hrs 00150 hist n 5439',
#  'insp a100 lh rh engine history recorder reading due due 15jul2018 upgrade x status 19jul2018 1 eng lcf1 0609 lcf2 3196 index3997 hours1083 2 eng lcf1 0993 lcf2 5776 index5588 hours2131 apu hours913 events3731',
#  'insp a100 lh rh engine history recorder reading due due 13sep2018 upgrade x status 17sep2018 1 eng lcf1 621 lcf2 3284 index4039 hours1099 2 eng lcf1 1005 lcf2 5864 index5622 hours2147 apu hours918 events3764',
#  'insp a022 14 day flyable storage engine run due 27sep2018 upgrade x status 29sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 15jul2018 upgrade x status 19jul2018 reading take',
#  'strap pack sn m2014 8606 require installation fail safe collar per h64 18sof02 24 jul 2019 comply h64 18sof02 instal collar n 10392558 0048 iaw rsn97e079r1 see 13 1 entry 01 date 23 sep 2018 related maintenance',
#  'strap pack sn m2014 8871 require installation fail safe collar per h64 18sof02 24 jul 2019 comply h64 18sof02 instal collar n 10392558 0244 iaw rsn97e079r1 see 13 1 entry 01 date 23 sep 2018 related maintenance',
#  'strap pack sn m2017 16681 require installation fail safe collar per h64 18sof02 24 jul 2019 comply h64 18sof02 instal collar n 10392558 0208 iaw rsn97e079r1 see 13 1 entry 01 date 23 sep 2018 related maintenance',
#  'strap pack sn m2017 17586 require installation fail safe collar per h64 18sof02 24 jul 2019 comply h64 18sof02 instal collar n 10043344 0783 iaw rsn97e079r1 see 13 1 entry 01 date 23 sep 2018 related maintenance',
#  'tr pitch link assembliy 1 inboard require proof load test per h64 18amam05 4675 7 aircraft hour sn verify co shop amam comply inspection complete',
#  'replace 2 aft lds cable cojunction next pms not exceed 4952 acft hour comply mec complete see fault 7 17oct2018',
#  'l540 sight assembly panel crake',
#  'l540 sight assembly panel crake replace',
#  'l540 sight assembly panel crake',
#  'l540 sight assembly panel crake',
#  'l540 sight assembly panel crake',
#  'l540 sight assembly panel crake replace',
#  'l540 sight assembly panel crake replace',
#  'l540 sight assembly panel crake replace',
#  'sm apu exhaust deflector stop drill mark repair crack fabricate doubler instal iaw 1 1520longbow apache see 2408 13 2 work complete',
#  '10 bracket crack 68 former replace bracket iaw tm1 1520longbow apache tm 1 1520 204 23 10 par 78',
#  'fwd leave efab ecs filter cover crack fwd left efab ecs filter cover replace',
#  'sm no 1 engine ln6 panel crack marked fault narrative previously write',
#  'r325 panel crack repair 1 22',
#  '1 fwd efab ecs filter mounting base crack write wrriten error',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp w tm 1 1520 280pmd',
#  'pmd inspection due comp w tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due complete iaw tm1 1520 280pmd',
#  'pmd inspection due complete iaw tm1 1520 280pmd',
#  'pmd inspection due compl ietm 1 1520 280pmd',
#  'pmd inspection due compl ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'insp a022 14 day flyable storage engine run due 09aug2018 upgrade x status 11aug2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 14sep2018 upgrade x status 18sep2018 reading take eng 1 lcf1 646 lcf2 2242 index 5899 hrs 1785 eng 2 lcf1 325 lcf2 854 index 2014 hrs 987',
#  'insp a100 lh rh engine history recorder reading due due 14jul2018 upgrade x status 18jul2018 reading take',
#  'insp a100 lh rh engine history recorder reading due due 13aug2018 upgrade x status 17aug2018 insp ok',
#  'insp a022 14 day flyable storage engine run due 25jul2018 upgrade x status 27jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 24aug2018 upgrade x status 26aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 11sep2018 upgrade x status 13sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 19sep2018 upgrade x status 21sep2018 engine run conjuction flight',
#  'insp a022 14 day flyable storage engine run due 20aug2018 upgrade x status 22aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 12sep2018 upgrade x status 14sep2018 complete',
#  'insp a022 14 day flyable storage engine run due 16jul2018 upgrade x status 18jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 10jul2018 upgrade x status 12jul2018 complete',
#  'insp a022 14 day flyable storage engine run due 30jul2018 upgrade x status 01aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 13aug2018 upgrade x status 15aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 21aug2018 upgrade x status 23aug2018 complete',
#  'insp a022 14 day flyable storage engine run due 05sep2018 upgrade x status 07sep2018 complete',
#  'insp a820 apu history recorder reading due due 12aug2018 upgrade x status 16aug2018 apu sn 806024 event 3242 hour 608',
#  'insp a100 lh rh engine history recorder reading due due 15sep2018 upgrade x status 19sep2018 complete',
#  'insp a100 lh rh engine history recorder reading due due 13jul2018 upgrade x status 17jul2018 complete',
#  'insp req starter complete',
#  'crack find previous repair r475 panel repair crack r475 panel iaw 1 1520longbow apache',
#  'tedac screen crack usable replace tdu sn 3347',
#  'cpg pedal adjustment cover cracked replace see fault date 24jul2018 event no 3001 related maintenance',
#  'crack inside panel r410 aft end shop stop drill crack',
#  'ln6 crack inside write error rn6 correct panel',
#  'r h fwd efab low shelf crack first rib',
#  'r h fwd efab low shelf crack first rib repair',
#  'crack low shelf 1st rib fwd efab',
#  'fuel boost pump cover crack',
#  'ln6 crack low rim repair',
#  '2 transmission bay longeron fwd upper hdwr rubber grommet crack replace',
#  'outboard edge fwd aft ecs filter cover crack cover replace',
#  'mount bracket barrel lock r200 panel crack reinstall panel crack fix',
#  'r h engine louver upper mount bracket crack complete pmi',
#  'pylon 1 nose fairing crack',
#  'pylon 1 nose fairing crack',
#  'flight control sweep require determine 3 feather bearing serviceability complete inspection',
#  'fault 1 date 20apr2018 helicopter 50hour incorrect defferral r pitch link bearing insp deffere 125hour a224insp iaw tm 1 1520longbow apache',
#  '2 inboard r pitch link assembly require proof load test per h64 18amam05 next 125 hr insp not exceed 5885 6 acft hour replace 2 inboard pitch link assy',
#  '13 1 dtd 27 july 18 entry 4 no iaw ref insp a805 sign insp a805 comp iaw tm 1 1520longbow apache conjunction pms',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw 1 1520 280pmd',
#  'pmd inspection due compl iaw 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp w tm 1 1520 280pmd',
#  'pmd inspection due comp w tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'insp a533 pitot static system inspection due 24aug2018 upgrade x status 24sep2018 complete system operational',
#  'removal inspection chip detector due no 1 eng remove reinstall',
#  'insp a851 daily visual inspection due instal equipment accordance awr date 744 r10 dtd 19jan17 tow ballast plate 966 r7 dtd 30sep15 fuel sample acc box 1037 r14 dtd 13jan17 satcom 1120 r10 dtd 29oct14 m240h 1270 r10 dtd 19oct15 eibf 1279 r6 dtd 20may16 cockpit door cabin windows rmvd 1308 r11 dtd 24apr15 int rescue hoist 1309 r10 dtd 11apr16 oregon aero seat cushion 1348 r12 dtd 13apr16 12pt ics 1407 r4 dtd 3jun16 night day hud 1444 r8 dtd 25may16 arhs 1466 r7 dtd 10aug15 garmin gps 1516 r10 dtd 23feb17 ebc elt 1520 r26 dtd 11mar16 flir 1539 r3 dtd 17jul14 apu ibf 1590 r6 dtd 29mar16 arn 147 elec base 1607 r8 dtd 14oct15 lead cdu pdu 1800 r5 dtd 27apr16 edm bft 1823 r5 dtd 13jan17 ivhms software 1886 r2 dtd 22oct15 hmu edecu 1896 r3 dtd 15jan16 gen 3 ecu w cmws due 5520 5 hour upgrade x status 5525 5 hour',
#  'insp a851 daily visual inspection due instal equipment accordance awr date 744 r10 dtd 19jan17 tow ballast plate 966 r7 dtd 30sep15 fuel sample acc box 1037 r14 dtd 13jan17 satcom 1120 r10 dtd 29oct14 m240h 1270 r10 dtd 19oct15 eibf 1279 r6 dtd 20may16 cockpit door cabin windows rmvd 1308 r11 dtd 24apr15 int rescue hoist 1309 r10 dtd 11apr16 oregon aero seat cushion 1348 r12 dtd 13apr16 12pt ics 1407 r4 dtd 3jun16 night day hud 1444 r8 dtd 25may16 arhs 1466 r7 dtd 10aug15 garmin gps 1516 r10 dtd 23feb17 ebc elt 1520 r26 dtd 11mar16 flir 1539 r3 dtd 17jul14 apu ibf 1590 r6 dtd 29mar16 arn 147 elec base 1607 r8 dtd 14oct15 lead cdu pdu 1800 r5 dtd 27apr16 edm bft 1823 r5 dtd 13jan17 ivhms software 1886 r2 dtd 22oct15 hmu edecu 1896 r3 dtd 15jan16 gen 3 ecu w cmws due 6516 0 hour upgrade x status 6521 0 hour',
#  'insp a851 daily visual inspection due instal equipment accordance awr date 744 r10 dtd 19jan17 tow ballast plate 966 r7 dtd 30sep15 fuel sample acc box 1037 r14 dtd 13jan17 satcom 1120 r10 dtd 29oct14 m240h 1270 r10 dtd 19oct15 eibf 1279 r6 dtd 20may16 cockpit door cabin windows rmvd 1308 r11 dtd 24apr15 int rescue hoist 1309 r10 dtd 11apr16 oregon aero seat cushion 1348 r12 dtd 13apr16 12pt ics 1407 r4 dtd 3jun16 night day hud 1444 r8 dtd 25may16 arhs 1466 r7 dtd 10aug15 garmin gps 1516 r10 dtd 23feb17 ebc elt 1520 r26 dtd 11mar16 flir 1539 r3 dtd 17jul14 apu ibf 1590 r6 dtd 29mar16 arn 147 elec base 1607 r8 dtd 14oct15 lead cdu pdu 1800 r5 dtd 27apr16 edm bft 1823 r5 dtd 13jan17 ivhms software 1886 r2 dtd 22oct15 hmu edecu 1896 r3 dtd 15jan16 gen 3 ecu w cmws due 7847 4 hour upgrade x status 7852 4 hour',
#  'insp a851 daily visual inspection due instal equipment accordance awr date 744 r10 dtd 19jan17 tow ballast plate 966 r7 dtd 30sep15 fuel sample acc box 1037 r14 dtd 13jan17 satcom 1120 r10 dtd 29oct14 m240h 1270 r10 dtd 19oct15 eibf 1279 r6 dtd 20may16 cockpit door cabin windows rmvd 1308 r11 dtd 24apr15 int rescue hoist 1309 r10 dtd 11apr16 oregon aero seat cushion 1348 r12 dtd 13apr16 12pt ics 1407 r4 dtd 3jun16 night day hud 1444 r8 dtd 25may16 arhs 1466 r7 dtd 10aug15 garmin gps 1516 r10 dtd 23feb17 ebc elt 1520 r26 dtd 11mar16 flir 1539 r3 dtd 17jul14 apu ibf 1590 r6 dtd 29mar16 arn 147 elec base 1607 r8 dtd 14oct15 lead cdu pdu 1800 r5 dtd 27apr16 edm bft 1823 r5 dtd 13jan17 ivhms software 1886 r2 dtd 22oct15 hmu edecu 1896 r3 dtd 15jan16 gen 3 ecu w cmws due 7863 8 hour upgrade x status 7868 8 hour',
#  'insp a851 daily visual inspection due instal equipment accordance awr date 744 r10 dtd 19jan17 tow ballast plate 966 r7 dtd 30sep15 fuel sample acc box 1037 r14 dtd 13jan17 satcom 1120 r10 dtd 29oct14 m240h 1270 r10 dtd 19oct15 eibf 1279 r6 dtd 20may16 cockpit door cabin windows rmvd 1308 r11 dtd 24apr15 int rescue hoist 1309 r10 dtd 11apr16 oregon aero seat cushion 1348 r12 dtd 13apr16 12pt ics 1407 r4 dtd 3jun16 night day hud 1444 r8 dtd 25may16 arhs 1466 r7 dtd 10aug15 garmin gps 1516 r10 dtd 23feb17 ebc elt 1520 r26 dtd 11mar16 flir 1539 r3 dtd 17jul14 apu ibf 1590 r6 dtd 29mar16 arn 147 elec base 1607 r8 dtd 14oct15 lead cdu pdu 1800 r5 dtd 27apr16 edm bft 1823 r5 dtd 13jan17 ivhms software 1886 r2 dtd 22oct15 hmu edecu 1896 r3 dtd 15jan16 gen 3 ecu w cmws due 7866 9 hour upgrade x status 7871 9 hour',
#  'insp a807 40 hour visual inspection vertical pilot copilot m4 carbine mount due 6523 1 hour upgrade x status 6527 2 hour insp ok',
#  'moc require disconnection reconnection cannon plug apu esu assy repair apu thermocouple wire complete',
#  'late entry comply h60 17amam12 airworthiness release update 23 sept 17 previously comply 23 aug 2018 5651 0 acft hrs',
#  '9 11 tq chk req sec 2 hdw due 3735 7 3737 7 write enter error',
#  'r hub tq chk zone 1 req pmi 2 tq chk complete tq 128 ft lbs tw sn2369',
#  '9 11 hour torque stabilization yellow main rotor blade tip cap screw due 2420 4 2422 4 acft hrs tq chk fail',
#  'adf ops chk req rmvd repl adf reciever insp comp',
#  'plt flight instrument light ops chk req rmvd reinst plt pdu bezel insp comp',
#  '9 11 tq ck black mr pc rod jamnut 3589 7 3591 7 acft hour complete pass 650 inlbs',
#  '9 11 tq ck blue mr pc rod jamnut 3589 7 3591 7 acft hour complete pass 650 inlbs',
#  '9 11 tq ck red mr pc rod jamnut 3589 7 3591 7 acft hour complete pass 650 inlbs',
#  'insp a296 inspect stabilator attach fitting due 3087 6 hour upgrade x status 3092 7 hour complete ck find ok',
#  'oil cooler vibe ck reqd completion pmi 1 complete',
#  '9 11 tq ck reqd r p c rod jamnut 8ea 5300 2 5302 2 hrs complete tq stab 650 lbs',
#  'r board retension plate tq ck due 6025 1 1 c hr comp',
#  'r pitch beam nut tq ck due 6025 1 1 c hr complete',
#  '9 11 hour tq ck reqd red r p c rod jam nut 4979 0 4981 0 acft hour pass 650 lbs tq stabilize',
#  '9 11 hour tq ck reqd r blue p c rod jam nut 4979 0 4981 0 acft hour pass 650 lbs tq stabilize',
#  'fire extinguisher bracket clamp inop inspect verified clamp operational condition no damage identify',
#  'comply h64 18sof02 main rotor strap pack inspection fail safe collar installation 01 aug 18 status enter error',
#  'strap pack sn m2016 968 require installation fail safe collar per h64 18sof02 24 jul 2019 fault find inspection see 2408 13 1 date 02sep2018 no 6 strap pack replacement',
#  'entry 2 date 12 aug 2018 sign incorrectly correct sign inspection complete 4 pass iaw h64 18sof pam 738 751',
#  'fault date 07 aug 2018 fault number 1 insp a535 first aid kit inspection sign without reference correction read replace first aid kit iaw em 0126',
#  'flight 90 110kta aircraft noticable vertical vibe inspect wedge pms instal new wedge blade 1 pocket 7 10 inch pocket 8 2 inch total 12 inch inspect next flight',
#  'oil find xmsn bay seep tailboom continue moniter daily inspection',
#  'no 1 longeron fwd bolt rubber washer not instal inspect verified rubber washer instal',
#  'pilot cpg first aid yellow tag miss first aid kit inspect tag instal',
#  'tlg fork assy groove headless pin require replacement due pit next 125hr inspection not replace status upgrade aircraft ground x status fault narrative enter erro',
#  'perform missile launcher inspection complete pmi',
#  '1 inboard r p c link corrosion bear rmvd inspect reinstld refer fault no 4 date 13jul18',
#  'tr pitch link assembly sn unk require proof load test per h64 18amam05 7065 9 proof load complete conjunction w phase refer fault 3007 4 june 2018',
#  'niu find fail not function apu power replace phase see phase book area 12 event 4006 replacement write',
#  '2 ngb aspi cover find crack preflight replacd',
#  'preflt plt station upper canopy leak water aft right aft left corner seat cushion wet ti verify multiple fault write single write not iaw da pams 738 751 see da form 2408 13 1 dtd 02 aug 2018 fault 3 4',
#  'pre flight izlid rubber tear internal wire show instal chafe tape',
#  'pre flight 1 strut need service service ground nitrogen nitrogen cart serial number co641',
#  'pre flight right side efab mumt back cannon plug wire rub metal shelf adjust harness correct routing',
#  'qc portion logbook recon number ar181970002 ar18130001 ar180390002 still open work complete accord 13 1 note',
#  'pmd inspection due com iaw tm 1 1520 280pmd',
#  'pmd inspection due com iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 150 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  '9 11 hour tq ck reqd black r p c rod jam nut 4979 0 4981 0 acft hour pass 650 lbs tq stabilize',
#  '9 11 hour tq ck reqd yellow r p c rod jam nut 4979 0 4981 0 acft hour pass 650 lbs tq stabilize',
#  'insp e108 ky58 pmcs opnl check standby due 19jul2018 upgrade x status 23jul2018 complete',
#  'insp e108 ky58 pmcs opnl check standby due 18aug2018 upgrade x status 22aug2018 complete',
#  'insp a502 inspect test ground receptacle iaw tm 1 1500 204 23 due 17sep2018 upgrade x status 06oct2018 complete check find ok',
#  'tail rotor cable tension check req 9 11 hour due 4414 5 4416 5 acft hrs stabalize l h 160 r h 175 temp 20c',
#  '9 11 hour main rotor head shaft nut bolt 4414 5 4416 5 acft hrs complete check find ok',
#  'perform operational check hydraulic pump module replacement main mod complete',
#  '9 11 hour torque check due 3552 1 3554 1 black r pc rod jam nut complete tq stabilize',
#  '9 11 hour torque check due 3552 1 3554 1 yellow r pc rod jam nut complete tq stabilize',
#  'insp e108 ky58 pmcs opnl check standby due 04sep2018 upgrade x status 08sep2018 check ok',
#  '9 11 hr cable tension check due 4865 7 4867 7 adjustment r cable tension set l h 181 r h 180 31 degree c',
#  '9 11 hr cable tension check due 4865 7 4867 7 adjustment r cable tension set l h 181 r h 180 31 degree c',
#  '40 hr tail pylon attachment bolt torque check require 4896 7 acft hrs second attempt',
#  '40 hr l h r h stabilator hinge fitting attachment bolt torque check require 4896 7 acft hrs',
#  '40 hr stabilator hinge fitting torque check 3rd check require 4936 7 acft hrs',
#  'oil cooler vibration check require removal reinstallation 1 drive shaft',
#  'oil cooler vibration check require removal reinstallation 1 drive shaft',
#  'tun req removal yaw position sensor pilot cockpit area check find',
#  'insp e108 ky58 pmcs opnl check standby due 11aug2018 upgrade x status 15aug2018 insp ok',
#  'quality control portion logbook recon follow fault toolbox inventory 4 date 20 july 18 1 10 july 18 7 10 july 18 aknowledge',
#  'replacement tdu due broken screen replace tdu sn 3347',
#  'coax cable rubbing ecu service panel aft pass thru bay instal lace tape',
#  'tail wheel strut need service service strut iaw em0126',
#  'tr pitch link asssembly sn require proof load test per h64 18amam05 7729 7 aircraft hour replace 1 inboard r p c link refer 2s n',
#  'tr pitch link assembly sn unk require proof load test per h64 18amam05 7228 0 complete',
#  'tr pitch link assembly sn unk require proof load test per h64 18amam05 7228 5 aircraft hour complete',
#  'tr pitch link assembly sn unk require proof load test per h64 18amam05 5716 9 aircraft hour p c link remove load test complete reinstall',
#  'no 5 drive shaft dampener fail spring test movement find 6 lbs fault write error',
#  'acft fault page show doppler test fault doppler malfunction ibit show doppler lef frequency track fail dplr sig data convrt cmputr fail fly post 250 hr could not duplicate',
#  'tr pitch link asssembly sn require proof load test per h64 18amam05 4922 6 aircraft hour complete',
#  'tr pitch link assembliy 1 inboard require proof load test per h64 18amam05 4675 7 aircraft hour',
#  'bft remain ti seek log see fault 1 date 06aug2018',
#  'nickel strip filler crack along edge strip not c w blade not use',
#  '1 engine oil drain valve leak',
#  'apu leak oil gear reduction shaft replace pack',
#  '2 eng hit check within 5 degree 11 limit 2416 establish baseline',
#  '3rd hit check 2 eng within 5 establish baseline',
#  '1 2 eng hit check within 5 low limit enter error student pilot use wrong chart',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
# ...
#  'insp e050 arc220 radio set battery inspection replace due 24aug2018 upgrade x status 28aug2018 complete check good',
#  'insp a501 main rotor blade spar pressure check due 11oct2018 upgrade x status 30oct2018 test complete isp ok',
#  'insp a501 main rotor blade spar pressure check due 11oct2018 upgrade x status 30oct2018 test complete isp ok',
#  'check swashplate ball bearing w hydraulic power wp0576install17 complete',
#  'check swashplate ball bearing w hydraulic power wp0576install17 complete',
#  'insp e108 ky58 pmcs opnl check standby due 24jul2018 upgrade x status 28jul2018 complete',
#  'insp e125 ky58 pmcs opnl check due 14aug2018 upgrade x status 24aug2018 insp complete',
#  'insp e108 ky58 pmcs opnl check standby due 23aug2018 upgrade x status 27aug2018 inspection complete',
#  'insp e108 ky58 pmcs opnl check standby due 22sep2018 upgrade x status 26sep2018 inspection complete',
#  'insp e108 ky58 pmcs opnl check standby due 04aug2018 upgrade x status 08aug2018 complete check find ok',
#  'insp e040 apr39 radar laser warning opnl check 5841 01 236 8951 due 20jul2018 upgrade x status 30jul2018 complete ok',
#  'op check left hand relay panel require complete find ok',
#  'insp e108 ky58 pmcs opnl check standby due 04jul2018 upgrade x status 08jul2018 insp complete',
#  'pilot copilot center post deflector insert remove due replacement center outboard window dupilicate write error refer acft logbook fault 3 18 july 2018 windshield show sign weather sand',
#  'pilot copilot center post deflector insert remove due replacement center outboard window dupilicate write error refer acft logbook fault 3 18 july 2018 windshield show sign weather sand',
#  'pilot copilot center post deflector insert remove due replacement center outboard window dupilicate write error refer acft logbook fault 3 18 july 2018 windshield show sign weather sand',
#  'pilot copilot center post deflector insert remove due replacement center outboard window dupilicate write error refer acft logbook fault 3 18 july 2018 windshield show sign weather sand',
#  'pilot copilot center post deflector insert remove due replacement center outboard window dupilicate write error refer acft logbook fault 3 18 july 2018 windshield show sign weather sand',
#  'government fqa complete',
#  'no 2 radio bad squelch transmit not servicable',
#  'no 2 radio bad squelch transmit not servicable',
#  'cabin floor puncture lh outter side vicinity sta 375 repair cabin floor st 375',
#  'lh stabilator attachment fitting inboard bushing wear replace bushing',
#  'tow acft tailwheel make loud screech noise bearing area get hot replace bearing',
#  '1 eng 93 would not excess 99 ng reinstall eng',
#  '2 pylon cover remove bulkhead reinstall',
#  'mlg drag beam remove',
#  'aircraft ground due lose tool lose tool report file rasm w2753c report 4140 not find aircraft release flight',
#  'apr39 control head not turn repair broken wire moc ok',
#  'current cdu instal wrong uh60a state total fuel require cdu state main fuel instal uh60l andor uh60a replace cdu sn1614 sn1603 replace sdc2 sn289 sn666',
#  'current cdu instal wrong uh60a state total fuel require cdu state main fuel instal uh60l andor uh60a replace cdu sn1614 sn1603 replace sdc2 sn289 sn666',
#  'remove ky100 jumper box install 8431 go e3 testing reinstall',
#  '1 gps would not come first 2 hour flight sign gps track satellite next start could not duplicate',
#  'ramp tongue sequencing valve intermitent operation ramp tongue come ramp come cause damage comb area ramp test sequence valve proper operation',
#  '1 tunnel cover no rubber bumper replace rubber bumper',
#  '1 tunnel cover no rubber bumper',
#  '5tunnel cover locking mechanism no rubber strip replace rubber strip',
#  '5tunnel cover locking mechanism no rubber strip',
#  '7 tunnel cover locking mechanism no rubber strip',
#  '7 tunnel cover locking mechanism no rubber strip replace rubber strip',
#  'combine transmission fwd adapter retain ring corrosion',
#  'combine transmission fwd adapter retain ring corrosion remove corrosion',
#  'ramp l h side airframe 1ea nut plate not instal mark replace nutplate',
#  'ramp l h side airframe 1ea nut plate not instal mark',
#  'ramp fwd b hinge assy damage middle beyond repair',
#  'ramp fwd b hinge assy damage middle beyond repair replace ramp fwd b leave side hinge assy',
#  'aft upper drive arm teflon wear beyond limit duplicate entry',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp w tm 1 1520 280pmd',
#  'pmd inspection due comp w tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due comp iaw tm1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'removal avionic equipment transponder mod avionic reinstall',
#  'number 1 engine power availible spindle not seat loose bracket correct fault replace pas lds support',
#  'no 1 hyd pump return line filter button extend replace filter element reset button service no 1 hydraulic system',
#  'removed yaw boost servo n 323 08142a control exchage aircraft 93 26473 boost servo replace',
#  'wear vertical stringer inboard side right k section repair 301 14hd 025 lot 851309',
#  '1 engine fire extinguisher discharge tube firewall elbow thread damage replace elbow',
#  'no 1 eng fail start replace no 1 pcl pid allen k deer dod 1025960420',
#  'yellow r paddle deice cannon plug back plate break include one two nutplate not instal repair cannon plug',
#  'afcs moc find roll trim actuator bad iaw em 0013 wp0168 suggest replacement replace actuator n c112 04273 actuator n c112 03390 iaw em 0013 wp 1100 00 wp 1127 00 wp 1131 00',
#  'main mod oil sump impend bypass button pop replace filter element',
#  'delamination lead edge bottom side near root main rotor yellow blade repair',
#  'l h drag beam mount damage beyond limit lh inboard bushing require replacement',
#  'yellow blue low scissor link bearing axial play great 0 014 inch replace bear',
#  'apu fail no 1 pcl advanced idle replace low oil pressure switch deservice oil proper level',
#  'bft modem require replacement due obsolete firmware replace modem iaw em 0013 wp 1635 03',
#  'mlg brake bleed prog k',
#  'mlg brake bleed prog k',
#  'mlg brake bleed prog k',
#  'l g lockpin bushing bore diameter limit',
#  'hydraulic fluid find seep 2 tranfer module q coupling',
#  'insp e125 ky58 pmcs opnl check due 25aug2018 upgrade x status 04sep2018 inspection complete',
#  'insp e108 ky58 pmcs opnl check standby due 02sep2018 upgrade x status 06sep2018 insp complete',
#  'insp e125 ky58 pmcs opnl check due 14aug2018 upgrade x status 24aug2018 complete insp ok',
#  'insp e108 ky58 pmcs opnl check standby due 21jul2018 upgrade x status 25jul2018 complete moc ok',
#  '9 11 hour tq check due black main rotor damper attachment hardware 6911 9 6913 9 aircraft hour complete',
#  'r cable tension check due 5487 3 5489 3 acft hrs cable set 150 lbs 22 c complete cable adjust 146 5 29 deg cel',
#  'r cable tension check due 5487 3 5489 3 acft hrs cable set 150 lbs 22 c complete cable adjust 146 5 29 deg cel',
#  'tq check due black r spindle control horn 5487 3 5489 3 acft hrs torque check complete pass',
#  'main rotor shaft seal require oil consumption check inspect find within limit',
#  'water leak check center windshield requiere due replacement center windshield complete',
#  'insp e220 emergency locator transmitter instal due 16jul2018 4711 3 upgrade x status 20jul2018 4716 30 check ok',
#  'tail rotor balance check req due tail rotor complete rig complete 0 05 ips',
#  'insp e040 apr39 radar laser warning opnl check 5841 01 236 8951 due 09oct2018 upgrade x status 19oct2018 comp',
#  '9 11 hr tq check rqrd 4141 4 4143 4 hrs red blue black yellow spindle mount hdwr due spindle replacement tq check ok',
#  '9 11 hr tq check rqrd 4141 4 4143 4 hrs yellow blue black red blade antiflap assys due rplcment spindle tq check ok',
#  'insp a501 main rotor blade spar pressure check due 31jul2018 upgrade x status 19aug2018 status symbol enter error',
#  'insp e108 ky58 pmcs opnl check standby due 02sep2018 upgrade x status 06sep2018 complete',
#  'insp e040 apr39 radar laser warning opnl check 5841 01 236 8951 due 13aug2018 upgrade x status 23aug2018 complete',
#  'fault6 system code 12jul2018moc due replacement clock battrie check find ok',
#  'insp a818 perform 10 hour14 day visual inspection iaw awr 1788 date 06 jan 17 r6 arn147 vor ils receiver mount due 28aug2018 5116 0 hour upgrade x status 30aug2018 5117 00 hour complete check find ok',
#  'aft upper drive arm teflon wear beyond limit',
#  'sm fwd l h work platform work rivet aft side hinge mark',
#  'sm fwd l h work platform work rivet aft side hinge mark replace work rivet',
#  'co pilot door slide window tube incorrectly fit',
#  'co pilot door slide window tube incorrectly fit instal correct orientation',
#  'sm no 1 pdp low bus bar guard bent guard straighten reinstall',
#  'sm no 1 pdp low bus bar guard bent',
#  'aft pylon butterfly cowl aft mount bolt secure rainshield cowling lack thread protusion dublicate fault refer seq number 3 date 22 jul 18',
#  'aft pylon butterfly cowl aft mount bolt secure rainshield cowling lack thread protusion',
#  'aft pylon position light cannon plug safety loose',
#  'aft pylon position light cannon plug safety loose safety replace',
#  'sm aft pylon avs inspection area inside fwd former top b rivet loose',
#  'sm aft pylon avs inspection area inside fwd former top b rivet loose tighten rivet',
#  'aft pylon r h eoms mount box require paint',
#  'aft pylon r h eoms mount box require paint aplie paint',
#  'aft pylon r h generator access panel area drain tube not instal drain tube instal',
#  'aft pylon r h generator access panel area drain tube not instal',
#  'aft pylon fmc mount proseal require hilock',
#  'aft pylon fmc mount proseal require hilock instal proseal',
#  'sm loose rivet 2ea 1 side stubby wing top edge mark red',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'insp a110 pms 40 hour inspection due 2129 6 hour upgrade x status 2131 7 hour comp iaw tm 1 1520 280pms',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'pmd inspection due comp iaw tm 1 1520 280pmd',
#  'pmd inspection due compl iaw ietm 1 1520 280pmd',
#  'satcom radio troubleshoot progress',
#  'satcom radio troubleshoot progress',
#  '2 satcom radio troubleshooting progress',
#  '2 satcom radio troubleshooting progress',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'bifiliar weights rmvd facilitate maintenance reinstall weight',
#  'insp e125 ky58 pmcs opnl check due 02sep2018 upgrade x status 12sep2018 inspection complete',
#  'r balance check require next flight due replacement r boot insp complete instal weight',
#  'insp e040 apr39 radar laser warning opnl check 5841 01 236 8951 due 07oct2018 upgrade x status 17oct2018 inspection complete',
#  'insp o833 inspect talon mms clean lens iaw manual check condition security due 29aug2018 upgrade x status 03sep2018',
#  'insp o833 inspect talon mms clean lens iaw manual check condition security due 13sep2018 upgrade x status 18sep2018',
#  'insp e040 apr39 radar laser warning opnl check 5841 01 236 8951 due 09oct2018 upgrade x status 19oct2018',
#  'insp e040 apr39 radar laser warning opnl check 5841 01 236 8951 due 20jul2018 upgrade x status 30jul2018 complete ok',
#  'insp e125 ky58 pmcs opnl check due 06aug2018 upgrade x status 16aug2018 insp comp check good',
#  'insp e125 ky58 pmcs opnl check due 19jul2018 upgrade x status 29jul2018 complete',
#  'command instrument operational check require disconnection cis processor complete',
#  'operational check require removal reinstallation left hand relay panel',
#  'operational check require removal reinstallation left hand relay panel complete find ok',
#  'function check reqd replacement 1st stage r servo pressure switch complete',
#  'insp a809 deice eot operational check due iaw tm 1 1520 237cl due 10aug2018 comp',
#  '9 11 hour torque check due 5524 4 5526 4 hour upper low red blue black yellow pc rod jamnut inspc complete',
#  '2 nd r drive shaft tq check due 7358 4 1 hr sec 2 2 drive shaft fwd hardware pass iaw em0013 wp 1745 00 mr92483 tq 330 inlbs',
#  'tail rotor outboard retention plate nut due torque check 7357 4 aircraft hour status change red x 7359 4 aircraft hour pass iaw em0013 wp1744 mr 92483 tq 627 ilbs',
#  'operational check r flight control system due removal r blade outboard retention plate pitch beam assy complete iaw tm 1 1520 237mtf',
#  'one time emc check require prior first flight new equipment instal iaw awr 2000 date 12 may 17 bft2 awr date enter error please see entry',
#  'one time emc check require prior first flight wth new equipment instal iaw awr 2000 date 31 may 18 bft2 previously complete like aircraft',
#  'sm loose rivet 2ea 1 side stubby wing top edge mark red replace loose rivet 2ea',
#  '1 aft work platform fwd latch insert worn replace',
#  '1 aft work platform fwd latch insert wear',
#  '1 butterfly cowl ground cable fray instal crimp broken ground cable',
#  'primary utility hydraulic sample due suspect contamination rsu aircraft ground administration pende result sample take iaw tm 1 1520longbow apache sapmle kit r hydkit2',
#  'primary utility hydraulic sample due suspect contamination rsu aircraft ground administration pende result sample take iaw tm 1 1520longbow apache sapmle kit r hydkit2',
#  'h f msl lau ibit due replacement lau sta 3 complete no fault find iaw em0126',
#  'h f msl lau ibit due replacement lau sta 3 complete no fault find iaw em0126',
#  'h f msl lau ibit due replacement lau sta 3 complete no fault find iaw em0126',
#  'h f msl lau ibit due replacement lau sta 3 complete iaw em0126',
#  'main rotor track balance due replacement damper rod end complete',
#  'removal ur rover 6 need due property transfer removal complete',
#  ...]

# %%
# Replace contractions
contraction_dict = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have"}

def _get_contractions(contraction_dict):
    contraction_re = re.compile('(%s)' % '|'.join(contraction_dict.keys()))
    return contraction_dict, contraction_re

contractions, contractions_re = _get_contractions(contraction_dict)

def replace_contractions(text):
    def replace(match):
        return contractions[match.group(0)]
    return contractions_re.sub(replace, text)

# Usage
#replace_contractions("this's a text with contraction")

contr_cleaned_text = []
for text in norm_corpus:
    contr_cleaned_text.append(replace_contractions(text))

# %%
print(df.xxxAllText[0:10])
print(contr_cleaned_text[0:10])
# Out:
# 0    ENG CHECKOUT PROCEDURE REQ PER TM 1-2840-248-2...
# 1    MOC/ CHECK PROCEDURE FOR NEW AND REINSTALLED E...
# 2    LMTF/MAX PWR CHECK REQUIRED FOR MAINTENANCE PE...
# 3    INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN ...
# 4    INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN ...
# 5    INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN ...
# 6    #2 ENG OIL COMSUMPTION CK REQ DUE TO OIL SEEPI...
# 7    MAIN MOD MOC/LEAK CHECK DUE ( MAIN MOD OIL FIL...
# 8    ENGINE LOAD DEMAND PUSH/PULL FRICTION CHECK RE...
# 9    RUN UP #2 ENGINE FOR AT LEAST 10 MINUTES. LET ...
# Name: xxxAllText, dtype: object
# ['eng checkout procedure req per tm 1 2840 248 23p wp 0111 table 1', 'moc check procedure new reinstall engine wp 0110 00 due maintenance perform 1 engine agb complete iaw tm 1 1520 237mtf', 'lmtf max pwr check require maintenance perform 1 engine agb per 1 2840 248 23p wp 0110 complete iaw tm 1 1520 237mtf', 'insp a022 14 day flyable storage engine run due 12jul2018 upgrade red x status 14jul2018 runup complete', 'insp a022 14 day flyable storage engine run due 26jul2018 upgrade x status 28jul2018 complete', 'insp a022 14 day flyable storage engine run due 26jul2018 upgrade x status 28jul2018 complete', '2 eng oil comsumption ck req due oil seeping c sump seal', 'main mod moc leak check due main mod oil filter replace drain plug remove reinstall moc complete fail leak check see fault 29 jul 18 3 iaw tm 1 1520 237mtf', 'engine load demand push pull friction check require removal lds cable support complete insp ok', 'run 2 engine least 10 minute let engine cool one hour minimum perform torque check 2 deswirl duct loop clamp nut tq chk comp']

# %%
# remove numbers
def clean_numbers(x):
    if bool(re.search(r'\d', x)):
        x = re.sub('[0-9]{5,}', '#####', x)
        x = re.sub('[0-9]{4}', '####', x)
        x = re.sub('[0-9]{3}', '###', x)
        x = re.sub('[0-9]{2}', '##', x)
    return x

num_contr_cleaned_text = []
for text in contr_cleaned_text:
    num_contr_cleaned_text.append(clean_numbers(text))

# %%
print(df.xxxAllText[0:10].values)
print(num_contr_cleaned_text[0:10])
# Out:
# ['ENG CHECKOUT PROCEDURE REQ PER TM 1-2840-248-23&P WP 0111 TABLE 1'
#  'MOC/ CHECK PROCEDURE FOR NEW AND REINSTALLED ENGINES WP 0110 00 DUE TO MAINTENANCE PERFORMED ON THE #1 ENGINE AGB COMPLETED IAW TM 1-1520-237-MTF'
#  'LMTF/MAX PWR CHECK REQUIRED FOR MAINTENANCE PERFORM ON THE #1 ENGINE AGB AND AS PER 1-2840-248-23&P WP 0110 COMPLETED IAW TM 1-1520-237-MTF'
#  'INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN UP. DUE AT: 12-JUL-2018. UPGRADE TO RED X STATUS ON 14-JUL-2018 RUNUP COMPLETE'
#  'INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN UP. DUE AT: 26-JUL-2018. UPGRADE TO X STATUS ON 28-JUL-2018 COMPLETED'
#  'INSP A022 - 14 DAY FLYABLE STORAGE ENGINE RUN UP. DUE AT: 26-JUL-2018. UPGRADE TO X STATUS ON 28-JUL-2018 COMPLETED'
#  '#2 ENG OIL COMSUMPTION CK REQ DUE TO OIL SEEPING FROM C-SUMP SEAL'
#  'MAIN MOD MOC/LEAK CHECK DUE ( MAIN MOD OIL FILTER REPLACED AND DRAIN PLUG REMOVED AND REINSTALLED) MOC COMPLETED, FAILED LEAK CHECK SEE FAULT # 29 JUL 18 #3 IAW TM 1-1520-237-MTF'
#  'ENGINE LOAD DEMAND PUSH/PULL FRICTION CHECK REQUIRED FOR REMOVAL OF LDS CABLE SUPPORTS COMPLETED, INSP OK'
#  'RUN UP #2 ENGINE FOR AT LEAST 10 MINUTES. LET ENGINE COOL DOWN FOR ONE HOUR MINIMUM. PERFORM A TORQUE CHECK OF THE #2 DESWIRL DUCT LOOP CLAMP NUTS TQ CHK COMP']
# ['eng checkout procedure req per tm 1 #### ### ##p wp #### table 1', 'moc check procedure new reinstall engine wp #### ## due maintenance perform 1 engine agb complete iaw tm 1 #### ###mtf', 'lmtf max pwr check require maintenance perform 1 engine agb per 1 #### ### ##p wp #### complete iaw tm 1 #### ###mtf', 'insp a### ## day flyable storage engine run due ##jul#### upgrade red x status ##jul#### runup complete', 'insp a### ## day flyable storage engine run due ##jul#### upgrade x status ##jul#### complete', 'insp a### ## day flyable storage engine run due ##jul#### upgrade x status ##jul#### complete', '2 eng oil comsumption ck req due oil seeping c sump seal', 'main mod moc leak check due main mod oil filter replace drain plug remove reinstall moc complete fail leak check see fault ## jul ## 3 iaw tm 1 #### ###mtf', 'engine load demand push pull friction check require removal lds cable support complete insp ok', 'run 2 engine least ## minute let engine cool one hour minimum perform torque check 2 deswirl duct loop clamp nut tq chk comp']

# %%
df['clean_text'] = num_contr_cleaned_text
df.to_csv('cleaned_corr_data.csv', encoding='utf-8', index=False)

# %%
import csv
# text that has been completely pre-processed
w = csv.writer(open("/Users/johncase/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/norm_corpus.csv", "w"))
for text in num_contr_cleaned_text:
    w.writerow([text])

# %% [markdown]
# # Need to drop identical rows - this makes the network train lazily and probably why training on all the data makes the attention mechanism less accurate!

# %%
df['clean_text']
# Out:
# 0          eng checkout procedure req per tm 1 #### ### #...
# 1          moc check procedure new reinstall engine wp ##...
# 2          lmtf max pwr check require maintenance perform...
# 3          insp a### ## day flyable storage engine run du...
# 4          insp a### ## day flyable storage engine run du...
#                                  ...
# 1406227          aft yellow rod end need replacement due pit
# 1406228    c box aux press swiitch not give signal replac...
# 1406229    rad alt back light inop preform operational pr...
# 1406230    aft green troop warning light inop could not r...
# 1406231    sta ### nvg cabin light inop replace 2 dome li...
# Name: clean_text, Length: 1406232, dtype: object

# %%
from progressbar import ProgressBar
pbar = ProgressBar()
seen = set()
uniq_docs = []
uniq_labels = []
for x, y in df[['clean_text','y']].values:
    if x not in seen:
        uniq_docs.append(x)
        uniq_labels.append(y)
        seen.add(x)

# %%
print(len(uniq_docs))
print(len(uniq_labels))
# Out:
# 336848
# 336848

# %%
uniq_df = pd.DataFrame()
uniq_df['clean_text'] = uniq_docs
uniq_df['y'] = uniq_labels
uniq_df.to_csv('unique_cleaned_corr_data.csv', encoding='utf-8', index=False)

# %%
# get duplicates only
pbar = ProgressBar()
seen = set() 
dupe = set(x for x in pbar(num_contr_cleaned_text) if x in seen or seen.add(x))
# Out:
# 100% |########################################################################|

# %%
len(dupe)
# Out:
# 275952

# %%
w = csv.writer(open("/Users/johncase/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/duplicates.csv", "w"))
for text in dupe:
    w.writerow([text])

# %% [markdown]
# ## Start here for new session (load pkgs...)

# %%
uniq_df = pd.read_csv('unique_cleaned_corr_data.csv')
uniq_df.clean_text = uniq_df.clean_text.astype(str)
uniq_df.dtypes
# Out:
# clean_text    object
# y              int64
# dtype: object

# %%
# tokenize text data
max_features = 10000
maxlen = 400

list_sentences = uniq_df['clean_text'].values
labels = uniq_df['y']

# Tokenize
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences))
list_tokenized = tokenizer.texts_to_sequences(list_sentences)

# create dictionaries to link words to their integer ids and the opposite
word2id = tokenizer.word_index
id2word = {v:k for k, v in word2id.items()}

# Split into train and test
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(list_tokenized, labels, test_size=0.2, random_state=42)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

# Pad
from keras.preprocessing import sequence
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# 269478 train sequences
# 67370 test sequences
# Pad sequences (samples x time)
# x_train shape: (269478, 400)
# x_test shape: (67370, 400)

# %%
#Once fit, the Tokenizer provides 4 attributes that you can use to query what has been learned about your documents:

#word_counts: A dictionary of words and their counts.
#word_docs: A dictionary of words and how many documents each appeared in.
#word_index: A dictionary of words and their uniquely assigned integers.
#document_count:An integer count of the total number of documents that were used to fit the Tokenizer
#print(t.word_counts)
print(tokenizer.document_count) # total number of docs
len(tokenizer.word_index) # total number of words in the vocab (originally 94819 without removing stopwords)
#print(t.word_docs)
# Out:
# 336848
# 41402

# %%
print(list_tokenized[0:5])

vocab_size = []
n=1
for doc in list_tokenized:
    if len(doc) != 0:
        vocab_size.append(max(doc))
    else:
        next
max(vocab_size)+1
# Out:
# [[92, 2309, 764, 126, 89, 30, 6, 59, 32, 1185, 6], [24, 20, 764, 186, 70, 28, 32, 1, 90, 45, 6, 28, 1858, 4, 10, 30, 6, 144], [694, 1018, 1020, 20, 14, 90, 45, 6, 28, 1858, 89, 6, 59, 32, 4, 10, 30, 6, 144], [3, 2, 35, 482, 395, 28, 135, 1, 19, 9, 125, 8, 7, 19, 1794, 4], [3, 2, 35, 482, 395, 28, 135, 1, 19, 9, 8, 7, 19, 4]]
# 10000

# %%
# number of words that only appear 5 times or less (originally 54236)
n = 0
for count in tokenizer.word_counts.values():
    if count < 5:
        n = n+1
print(n)
# I NEED TO DROP THESE WORDS FROM THE VOCAB
# Out:
# 30006

# %%
# find max document length (originally 2483)
# lengths = []
# for doc in uniq_docs:
#     lengths.append(len(doc))
# max(lengths)

# %%
from collections import Counter

trd = dict(Counter(y_train))
tsd = dict(Counter(y_test))

(pd.DataFrame([[key, trd[key], tsd[key]] for key in trd],
            columns=['Target Label', 'Train Count', 'Test Count'])
 .sort_values(by=['Train Count', 'Test Count'], ascending=False))
# Out:
#    Target Label  Train Count  Test Count
# 1             1       202000       50338
# 0             0        67478       17032

# %% [markdown]
# ### Bring in the pre-trained embeddings and load into embedding layer

# %%
# load the model 
from keras.models import load_model
# creates a HDF5 file 
model_embeds = load_model('/Users/mh302/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/skip_grm_model.h5')
# Out:
# /Users/mh302/opt/anaconda3/envs/tensorflow_cpu/lib/python3.6/site-packages/tensorflow_core/python/framework/indexed_slices.py:424: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
#get the word embeddings
word_embed_layer = model_embeds.layers[2]
weights = word_embed_layer.get_weights()[0][0:]
print(weights.shape)
# Out:
# (41403, 100)

# %%
# create a dictionary (embeddings_index) of words to weights (or embedding vectors)
embeddings_index = {}
f = open('word_embeddings_df.csv') # this is embeddings and their words from SkipGramModel with window=10, epochs = 5
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 41403 word vectors.

# %%
# link the word embedding weights to the token indices from the preprocessed documents
#word_embeddings_df = pd.DataFrame(weights, index=id2word.values())
#word_embeddings_df.head()
embed_size = 100

embedding_matrix = np.zeros((len(word2id) + 1, embed_size))
for word, i in word2id.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
#build the Attention layer
from keras.layers import Activation, Concatenate, Permute, SpatialDropout1D, RepeatVector, LSTM, Bidirectional, Multiply, Lambda, Dense, Dropout, Input,Flatten,Embedding
from keras.models import Model
import keras.backend as K

class Attention:
    def __call__(self, inp, combine=True, return_attention=True):
        # Expects inp to be of size (?, number of words, embedding dimension)
        
        repeat_size = int(inp.shape[-1])
        
        # Map through 1 Layer MLP
        x_a = Dense(repeat_size, kernel_initializer = 'glorot_uniform', activation="tanh", name="tanh_mlp")(inp) 
        
        # Dot with word-level vector
        x_a = Dense(1, kernel_initializer = 'glorot_uniform', activation='linear', name="word-level_context")(x_a)
        x_a = Flatten()(x_a) # x_a is of shape (?,200,1), we flatten it to be (?,200)
        att_out = Activation('softmax')(x_a) 
        
        # Clever trick to do elementwise multiplication of alpha_t with the correct h_t:
        # RepeatVector will blow it out to be (?,120, 200)
        # Then, Permute will swap it to (?,200,120) where each row (?,k,120) is a copy of a_t[k]
        # Then, Multiply performs elementwise multiplication to apply the same a_t to each
        # dimension of the respective word vector
        x_a2 = RepeatVector(repeat_size)(att_out)
        x_a2 = Permute([2,1])(x_a2)
        out = Multiply()([inp,x_a2])
        
        if combine:
        # Now we sum over the resulting word representations
            out = Lambda(lambda x : K.sum(x, axis=1), name='expectation_over_words')(out)
        
        if return_attention:
            out = (out, att_out)
                   
        return out

# %%
# train a Bi-Directional LSTM to demonstrate the Attention class. The Bidirectional class in Keras 
#returns a tensor with the same number of time steps as the input tensor, but with the forward and 
#backward pass of the LSTM concatenated. The standard dimensions for this use case in Keras is: 
#(batch size, time steps, word embedding dimension).
lstm_shape = 60


# Define the model
inp = Input(shape=(maxlen,))
emb = Embedding(input_dim=max_features, input_length = maxlen, output_dim=embed_size,
                    trainable=False)(inp)
x = SpatialDropout1D(0.35)(emb)
x = Bidirectional(LSTM(lstm_shape, return_sequences=True, dropout=0.15, recurrent_dropout=0.15))(x)
x, attention = Attention()(x)
x = Dense(1, activation="sigmoid")(x)

model = Model(inputs=inp, outputs=x)
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

attention_model = Model(inputs=inp, outputs=attention) # Model to print out the attention data

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 400)          0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 400, 100)     1000000     input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 400, 100)     0           embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 400, 120)     77280       spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# tanh_mlp (Dense)                (None, 400, 120)     14520       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# word-level_context (Dense)      (None, 400, 1)       121         tanh_mlp[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 400)          0           word-level_context[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 400)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 120, 400)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 400, 120)     0           repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 400, 120)     0           bidirectional_1[0][0]
#                                                                  permute_1[0][0]
# __________________________________________________________________________________________________
# expectation_over_words (Lambda) (None, 120)          0           multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            121         expectation_over_words[0][0]
# ==================================================================================================
# Total params: 1,092,042
# Trainable params: 92,042
# Non-trainable params: 1,000,000
# __________________________________________________________________________________________________

# %%
#from keras.utils import plot_model
#import pydotplus as pydot

# %%
#pydot.find_graphviz()

# %%
# plot graph #USED python3 in tensorflow_cpu venv in the terminal to do this...
#plot_model(model, to_file='bidir_lstm_attn_graph.png')

# %%
# Fit the model
history = model.fit(x_train, y_train, validation_split=.2, epochs=3, verbose=1, batch_size=512)
# Out:
# Train on 215582 samples, validate on 53896 samples
# Epoch 1/3
# 215582/215582 [==============================] - 531s 2ms/step - loss: 0.5654 - accuracy: 0.7486 - val_loss: 0.5651 - val_accuracy: 0.7487
# Epoch 2/3
# 215582/215582 [==============================] - 537s 2ms/step - loss: 0.5631 - accuracy: 0.7498 - val_loss: 0.5637 - val_accuracy: 0.7487
# Epoch 3/3
# 215582/215582 [==============================] - 517s 2ms/step - loss: 0.4777 - accuracy: 0.7546 - val_loss: 0.4304 - val_accuracy: 0.7666

# %%
reverse_token_map = dict(map(reversed, tokenizer.word_index.items()))

# %%
# Error with reverse_token_map not defined...
def get_word_importances(text):
    lt = tokenizer.texts_to_sequences([text])
    x = pad_sequences(lt, maxlen=maxlen)
    p = model.predict(x)
    att = attention_model.predict(x)
    return p, [(reverse_token_map.get(word), importance) for word, importance in zip(x[0], att[0]) if word in reverse_token_map]

# %%
#get_word_importances(df['clean_text'].values[2])
get_word_importances('debond')
# Out:
# (array([[0.57876915]], dtype=float32), [('debond', 0.7457179)])

# %%
from progressbar import ProgressBar

# %%
pbar = ProgressBar()
att_dict = {}
for text in pbar(uniq_df['clean_text']):
    lt = tokenizer.texts_to_sequences([text])
    x = pad_sequences(lt, maxlen=maxlen)
    att = attention_model.predict(x)
    for word, importance in zip(x[0], att[0]): 
        if word in reverse_token_map:
            att_dict[str(reverse_token_map.get(word))] = importance
# Out:
# 100% |########################################################################|

# %%
# import multiprocessing
# from joblib import Parallel, delayed
# from tqdm import tqdm

# num_cores = multiprocessing.cpu_count()

# inputs = tqdm(uniq_df['clean_text'])

# #did this earlier: list_tokenized_train = tokenizer.texts_to_sequences(list_sentences)

# # Pad sequenses, did this earlier: X_t = pad_sequences(list_tokenized_train, maxlen=maxlen)

# def my_function(text, tokenizer=tokenizer, maxlen=maxlen, attention_model=attention_model):
#     att_dict = {} # start from scratch with each line of text
#     lt = tokenizer.texts_to_sequences([text]) # tokenize the words to sequences
#     x = pad_sequences(lt, maxlen=maxlen) # pad the sequences
#     att = attention_model.predict(x) # get word importance
#     for word, importance in zip(x[0], att[0]): # for each word (key) and its importance (value), write to att_dict
#         if word in reverse_token_map:
#             att_dict[str(reverse_token_map.get(word))] = importance
#     return att_dict # return the key, value pairs

# if __name__ == "__main__":  #protects the entry point of the program 
#     processed_list = Parallel(n_jobs=num_cores)(delayed(my_function)(text) for text in inputs)

# %%
import csv

w = csv.writer(open("/Users/mh302/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/att_dict_attn_mdl_pretrnd_embd_fixed.csv", "w"))
for key, val in att_dict.items():
    w.writerow([key, val])

# %%
important_words = sorted(att_dict, key=att_dict.__getitem__, reverse=True)[0:50]
important_words
# Out:
# ['reimage',
#  'braket',
#  'reisnt',
#  'mlp',
#  'x1',
#  'arch',
#  'override',
#  'wpf2c0',
#  'completetd',
#  'reistalle',
#  'mhe',
#  'requ',
#  'mwc',
#  'injector',
#  'inprogess',
#  'expire',
#  'gladhand',
#  'cancel',
#  'mrsgk',
#  'lo',
#  'camera',
#  'period',
#  'experimental',
#  'prov',
#  'discolour',
#  'nrts1',
#  'dol',
#  'lad',
#  'bond',
#  'compensator',
#  'propperly',
#  'christopherson',
#  'prong',
#  'tensioner',
#  'ecod',
#  'initialization',
#  'ggact',
#  'repace',
#  'position',
#  'reservicee',
#  'matsu',
#  '5a',
#  'intershop',
#  'make',
#  'reintalle',
#  'accumalator',
#  'auker',
#  'pvs6',
#  'wykj',
#  'inventorie']

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
import matplotlib.pyplot as plt

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for "blue dot"
plt.plot(epochs, loss, 'r', label='Training loss')
# b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()

plt.show()

# %% [markdown]
# https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/3.5-classifying-movie-reviews.ipynb

# %%
#model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
# https://machinelearningmastery.com/how-to-calculate-precision-recall-f1-and-more-for-deep-learning-models/ 
# predict probabilities for test set
yhat_probs = model.predict(x_test, verbose=0)
# predict crisp classes for test set
yhat_classes = [round(pred[0]) for pred in yhat_probs]
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
#yhat_classes = yhat_classes[:, 0]
 
# accuracy: (tp + tn) / (p + n), the ratio of correctly predicted observation to the total observations.
accuracy = accuracy_score(y_test, yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp), the ratio of correctly predicted positive observations to the total predicted positive observations
# If precision is high, we are making correct corrosion tags, but possibly missing corrosion items
precision = precision_score(y_test, yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn), ratio of correctly predicted positive observations to the all observations in actual class
# So if recall is low, we are missing actual corrosion actions
recall = recall_score(y_test, yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn), the weighted average of Precision and Recall
# If this is high, we are making correct corrosion tags and not missing actions that should be corrosion.
f1 = f1_score(y_test, yhat_classes)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.764984
# Precision: 0.765803
# Recall: 0.987445
# F1 score: 0.862614

# %%
# Save or load the model
from keras.models import load_model
# creates a HDF5 file 
model.save('/Users/mh302/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/atn_model_norm_corpus_unique_pretrn_emb_fixed.h5')

# %%
from keras.models import load_model
model = load_model('/Users/mh302/OneDrive - West Point/Backup/ORCEN/CPO/deep_learning/atn_model_norm_corpus_unique_pretrn_emb_fixed.h5')
